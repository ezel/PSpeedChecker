# %%
import pandas as pd
import numpy as np

# %%
import export_vis as m
d1 = m.init_base('pokedex.json')
d2 = m.init_draw_test(12)
d2
# Out:
#                  num              name    type1    type2  base_spe  \
# togekiss         468          Togekiss    Fairy   Flying        80
# steenee          762           Steenee    Grass     None        62
# groudonprimal    383    Groudon-Primal   Ground     Fire        90
# metagross        376         Metagross    Steel  Psychic        70
# poipole          803           Poipole   Poison     None        73
# honedge          679           Honedge    Steel    Ghost        28
# tornadustherian  641  Tornadus-Therian   Flying     None       121
# woobat           527            Woobat  Psychic   Flying        72
# diglett           50           Diglett   Ground     None        95
# pumpkaboosmall   710   Pumpkaboo-Small    Ghost    Grass        56
# feebas           349            Feebas    Water     None        80
# surskit          283           Surskit      Bug    Water        65
#
#                  stats_nnzero  stats_nniv  stats_noev  stats_evmax  \
# togekiss                   76          90         100          132
# steenee                    60          74          82          114
# groudonprimal              85          99         110          142
# metagross                  67          81          90          122
# poipole                    70          84          93          125
# honedge                    29          43          48           80
# tornadustherian           113         127         141          173
# woobat                     69          83          92          124
# diglett                    90         103         115          147
# pumpkaboosmall             54          68          76          108
# feebas                     76          90         100          132
# surskit                    63          76          85          117
#
#                  stats_npnoev  stats_nmax
# togekiss                  110         145
# steenee                    90         125
# groudonprimal             121         156
# metagross                  99         134
# poipole                   102         137
# honedge                    53          88
# tornadustherian           155         190
# woobat                    101         136
# diglett                   127         161
# pumpkaboosmall             84         118
# feebas                    110         145
# surskit                    94         128

# %%
m.draw(d2)
# Out:
# alt.LayerChart(...)

# %%
import altair as alt

source2 = d2

mybase = alt.Chart(source2).encode(
    alt.X('name:O',
          axis=alt.Axis(
              labelAngle=-45,
              title='Pokemon Name'
          ),
    ),
    color=alt.value("#06982d")
)

myrule = mybase.mark_bar().encode(
    alt.Y(
        'stats_npnoev:Q',
        title='Stats'
    ),
    alt.Y2('stats_nmax:Q'),
    color=alt.value("#ffff30")
)

mybar = mybase.mark_bar().encode(
    alt.Y('stats_nnzero:Q'),
    alt.Y2('stats_nniv:Q'),
    color=alt.value("#ff2030")
)

mybar2 = mybase.mark_bar().encode(
    alt.Y('stats_noev:Q'),
    alt.Y2('stats_evmax:Q'),
    color=alt.value("#20ff30")
)

tick = mybase.mark_tick().encode(
    alt.Y('stats_npnoev:Q'),
    color=alt.value('#000000')
)

line = mybase.mark_line(stroke='#5276A7', interpolate='monotone').encode(
    alt.Y('base_spe',
          axis=alt.Axis(title='Base', titleColor='#5276A7'))
)

chart = alt.layer(myrule+mybar+mybar2+tick, line).resolve_scale(
    y = 'independent'
)

chart
# Out:
# alt.LayerChart(...)
